# %% [markdown]
# <a href="https://colab.research.google.com/github/YerryRumbrapuk/TugasMachineLearning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = '/content/drive/MyDrive/YeryRumbrapuk/TM9/dataseet/Dataset_1.csv'
df = pd.read_csv(data)

# %%
df.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0 -1.032690  2.096221  0.384194 -1.214555  2.432575  1.069743 -1.076878
# 1 -0.509585 -0.896533 -0.465612  0.033544 -0.781463 -0.934908  0.061976
# 2 -1.032690 -0.896533  1.243594 -1.101241 -0.781463 -0.934908 -0.355857
# 3 -1.024914  1.367049  0.014966 -1.141605  1.102526  0.197138 -0.921322
# 4  1.585219 -0.896533 -0.782318  0.692780 -0.781463  0.732274 -0.113010
#
#          x8        x9       x10  ...      x248      x249      x250      x251  \
# 0  2.140959  0.403971 -1.039528  ...  2.423807  0.833363 -0.932956  2.047133
# 1 -0.712155 -0.929289 -0.624238  ... -0.783508 -0.877666  0.084089 -0.718668
# 2 -0.020836 -0.726172 -1.039528  ... -0.783508 -0.851601 -0.481456  0.041508
# 3  1.064377  0.235659 -0.973558  ...  1.228601  0.089344 -0.932956  1.093751
# 4 -1.048795  1.248580  1.636419  ... -0.783508  0.902548  0.000080 -1.049062
#
#        x252      x253      x254      x255      x256  label
# ...

# %%
df.shape
# Out:
# (3264, 257)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3264 entries, 0 to 3263
# Columns: 257 entries, x1 to label
# dtypes: float64(256), int64(1)
# memory usage: 6.4 MB

# %%
sns.pairplot(df, vars=['x1', 'x2', 'x3', 'x4', 'x5'], hue='label')
plt.title('Pairplot of Features')
plt.show()

# %%
df.drop('label', axis=1).hist(bins=20, figsize=(20, 15))
plt.suptitle('Histogram of Features', x=0.5, y=0.92, fontsize=20)
plt.show()

# %%
df.isnull().sum()
# Out:
# x1       0
# x2       0
# x3       0
# x4       0
# x5       0
#         ..
# x253     0
# x254     0
# x255     0
# x256     0
# label    0
# Length: 257, dtype: int64

# %%
X = df.drop(['label'], axis=1)

y = df['label']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
X_train.shape, X_test.shape
# Out:
# ((2284, 256), (980, 256))

# %%
X_train.dtypes
# Out:
# x1      float64
# x2      float64
# x3      float64
# x4      float64
# x5      float64
#          ...
# x252    float64
# x253    float64
# x254    float64
# x255    float64
# x256    float64
# Length: 256, dtype: object

# %%
X_train.isnull().sum()
# Out:
# x1      0
# x2      0
# x3      0
# x4      0
# x5      0
#        ..
# x252    0
# x253    0
# x254    0
# x255    0
# x256    0
# Length: 256, dtype: int64

# %%
X_test.isnull().sum()
# Out:
# x1      0
# x2      0
# x3      0
# x4      0
# x5      0
#        ..
# x252    0
# x253    0
# x254    0
# x255    0
# x256    0
# Length: 256, dtype: int64

# %%
cols = X_train.columns

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns=[cols])
X_test = pd.DataFrame(X_test, columns=[cols])

# %%
X_train.head()
# Out:
#          x1        x2        x3        x4        x5        x6        x7  \
# 0 -0.423807  1.098512 -0.062269 -0.701804  1.226466  0.205108 -0.606869
# 1 -0.423807  1.282175  0.590470 -0.701804  1.583154  0.511024 -0.454287
# 2  0.811151  0.895929  0.098861 -0.355044 -0.129649  0.795311  0.939392
# 3  0.279497  0.840928  0.111564  0.038809  0.713798  0.254753 -0.517092
# 4  0.154545 -0.378349  0.126489  0.449558 -0.129649 -0.439857  0.802785
#
#          x8        x9       x10  ...      x247      x248      x249      x250  \
# 0  0.844810 -0.013189 -0.409092  ... -0.640453  1.140965  0.170187 -0.488079
# 1  0.761647  0.473420 -0.409092  ... -0.640453  1.535851  0.380846 -0.488079
# 2 -0.010513 -0.624620  0.861903  ... -0.243167 -0.035461  0.789729  0.884681
# 3  0.732194  0.429034  0.363924  ... -0.022184  0.734143  0.169879 -0.488079
# 4  0.053210 -0.624620  0.096258  ...  0.428398 -0.171247 -0.417143  0.800747
#
#        x251      x252      x253      x254      x255      x256
# ...

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

y_pred
# Out:
# array([1, 2, 0, 3, 3, 3, 1, 2, 0, 3, 2, 3, 2, 3, 3, 3, 2, 3, 3, 2, 1, 1,
#        0, 0, 1, 3, 2, 2, 0, 0, 3, 3, 0, 0, 3, 2, 2, 3, 2, 3, 3, 0, 0, 2,
#        1, 3, 3, 3, 1, 3, 3, 2, 3, 0, 0, 2, 0, 1, 1, 0, 0, 3, 2, 0, 2, 0,
#        3, 2, 3, 3, 2, 3, 0, 2, 1, 2, 0, 3, 3, 2, 2, 1, 3, 3, 3, 2, 1, 0,
#        3, 0, 0, 2, 0, 2, 1, 3, 1, 3, 3, 1, 3, 3, 0, 3, 0, 0, 3, 2, 0, 0,
#        0, 0, 3, 3, 3, 3, 0, 0, 0, 3, 1, 3, 0, 2, 0, 3, 2, 1, 3, 1, 0, 3,
#        3, 0, 0, 0, 3, 3, 0, 1, 1, 1, 3, 0, 3, 1, 0, 0, 2, 3, 1, 3, 3, 1,
#        0, 3, 0, 0, 0, 2, 3, 1, 3, 3, 3, 3, 0, 3, 0, 3, 3, 3, 3, 3, 3, 2,
#        2, 3, 2, 0, 0, 3, 1, 3, 1, 1, 0, 1, 1, 2, 3, 0, 0, 2, 0, 3, 3, 3,
#        2, 0, 2, 1, 3, 2, 1, 3, 0, 3, 3, 0, 3, 0, 0, 3, 3, 3, 3, 0, 0, 3,
#        1, 3, 2, 1, 0, 0, 0, 0, 3, 0, 3, 0, 3, 2, 0, 3, 0, 1, 0, 1, 1, 3,
#        3, 3, 0, 3, 2, 2, 1, 2, 3, 3, 1, 3, 1, 1, 0, 2, 2, 3, 3, 0, 1, 0,
#        0, 3, 0, 0, 3, 2, 3, 3, 3, 3, 3, 0, 3, 2, 1, 2, 3, 1, 3, 2, 0, 2,
# ...

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score: 0.6082

# %%
y_pred_train = gnb.predict(X_train)

y_pred_train
# Out:
# array([3, 3, 1, ..., 3, 0, 1])

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# Out:
# Training-set accuracy score: 0.5954

# %%
print('Training set score: {:.4f}'.format(gnb.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(gnb.score(X_test, y_test)))
# Out:
# Training set score: 0.5954
# Test set score: 0.6082

# %%
y_test.value_counts()
# Out:
# label
# 1    291
# 0    272
# 3    269
# 2    148
# Name: count, dtype: int64

# %%
majority_count = 291  # Jumlah sampel kelas 1
total_samples = 291 + 272 + 269 + 148  # Jumlah semua sampel
null_accuracy = majority_count / total_samples

print('Null accuracy score: {0:0.4f}'. format(null_accuracy))
# Out:
# Null accuracy score: 0.2969

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print('Confusion matrix\n\n', cm)

print('\nTrue Positives(TP) = ', cm[0,0])

print('\nTrue Negatives(TN) = ', cm[1,1])

print('\nFalse Positives(FP) = ', cm[0,1])

print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[181  34  18  39]
#  [ 73 108  55  55]
#  [ 18  18  88  24]
#  [ 30  14   6 219]]
#
# True Positives(TP) =  181
#
# True Negatives(TN) =  108
#
# False Positives(FP) =  34
#
# False Negatives(FN) =  73

# %%
cm = [[181, 34, 18, 39],
      [73, 108, 55, 55],
      [18, 18, 88, 24],
      [30, 14, 6, 219]]

# %%
cm_matrix = pd.DataFrame(data=cm,
                        columns=['Actual Class 0', 'Actual Class 1', 'Actual Class 2', 'Actual Class 3'],
                        index=['Predicted Class 0', 'Predicted Class 1', 'Predicted Class 2', 'Predicted Class 3'])

plt.figure(figsize=(10,7))
sns.heatmap(cm_matrix, annot=True, fmt='d', cmap='YlGnBu')
plt.xlabel('Actual Label')
plt.ylabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.67      0.63       272
#            1       0.62      0.37      0.46       291
#            2       0.53      0.59      0.56       148
#            3       0.65      0.81      0.72       269
#
#     accuracy                           0.61       980
#    macro avg       0.60      0.61      0.59       980
# weighted avg       0.61      0.61      0.60       980

# %%
cm = np.array([[181, 34, 18, 39],
              [73, 108, 55, 55],
              [18, 18, 88, 24],
              [30, 14, 6, 219]])
TP = cm[0,0]
TN = cm[1,1]
FP = cm[0,1]
FN = cm[1,0]

# %%
classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)

print('Classification accuracy : {0:0.4f}'.format(classification_accuracy))
# Out:
# Classification accuracy : 0.7298

# %%
classification_error = (FP + FN) / float(TP + TN + FP + FN)

print('Classification error : {0:0.4f}'.format(classification_error))
# Out:
# Classification error : 0.2702

# %%
precision = TP / float(TP + FP)


print('Precision : {0:0.4f}'.format(precision))
# Out:
# Precision : 0.8419

# %%
recall = TP / float(TP + FN)

print('Recall or Sensitivity : {0:0.4f}'.format(recall))
# Out:
# Recall or Sensitivity : 0.7126

# %%
true_positive_rate = TP / float(TP + FN)


print('True Positive Rate : {0:0.4f}'.format(true_positive_rate))
# Out:
# True Positive Rate : 0.7126

# %%
false_positive_rate = FP / float(FP + TN)


print('False Positive Rate : {0:0.4f}'.format(false_positive_rate))
# Out:
# False Positive Rate : 0.2394

# %%
specificity = TN / (TN + FP)

print('Specificity : {0:0.4f}'.format(specificity))
# Out:
# Specificity : 0.7606
